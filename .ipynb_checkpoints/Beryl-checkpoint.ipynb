# %%
# !pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("height-weight.csv")

# %%
df
# Out:
#     Weight  Height
# 0       45     120
# 1       58     135
# 2       48     123
# 3       60     145
# 4       70     160
# 5       78     162
# 6       80     163
# 7       90     175
# 8       95     182
# 9       78     170
# 10      82     176
# 11      95     182
# 12     105     175
# 13     100     183
# 14      85     170
# 15      78     177
# 16      50     140
# 17      65     159
# 18      76     150
# 19      87     167
# 20      45     129
# 21      56     140
# 22      72     160
